# %% [markdown]
# # Python Homework (Flow Control, Modules, Functions, Exceptions, NumPy)
#
# **Note**: You can create a Python file or a Jupyter Notebook file
#
# <br>
#
# **<ins>Use markdown formatting for the following questions (e.g., bold lettering, bullet points, different font sizes, etc.)</ins>**:
#
# 1. What does one need to do to use a module?
#
#     - Import the respective module into our code-base. by using the import statement.
#
# 1. Name a Module (not the DateTime Nodule) we looked at and write a line or 2 of code as an example using this module.
#
#     - import random
#
#         diceThrow=random.randrange(1,21)
#         print("Dice throw ...", diceThrow)
#
#         prob = random.random()
#         print("Probability ...", prob)
#
#         orderedList = ["apple", "banana", "cherry"]
#         random.shuffle(orderedList)
#         print("Shuffled List ...", orderedList)
#
# 1. What is a benefit of using Exception handling?
#
#     - Stops unexpected errors like a missing file or bad user input from shutting down the entire program.
#     - Displays helpful, custom error messages instead of raw, confusing system failures.
#
# 1. what are the 4 components used for Python Exception Handling?
#
#     - try, except, else, finally
#
# 1. NumPy arrays are like what Python data type?
#
#     - pyhon lists
#
# 1. What is one of the main benefits of using NumPy arrays.
#
#     - NumPy supports operations on entire arrays at once without needing explicit for loops in your Python code.
#     - Store data in a single, continuous block of memory that allows the computer's processor to load and access data much more quickly.
#
# 1. What is one of the main requirements about the 'dtype' of NumPy arrays?
#
#     - You cannot mix different basic data types.  If you try to create an array with mixed types, NumPy automatically converts (coerces) the elements into
#       a single compatible type.
#
# 1. Of the 10 uses of NumPy, name 2.
#
#     - Data Analysis
#     - Machine Learning
#
# 1. Name one of the other libraries we'll use with NumPy?
#
#     - Pandas
#
# 1. What is the shape of NumPy arrays?
#
#     - tuple of integers (it depends on the number of dimensions you use 1D, 2D, 3D)
#
# 1. What is a Tensor?
#
#     - A multidimensional data array used as a container for numerical data.
#
# 1. Name a reason why it's better using  NumPy for Data Analysis than using a Python List?
#
#     - computational speed and memory efficiency. Vectorization meaning no loops needed, and computer optimization.
#
# 1. When creating an "empty" array, where do the elements come from?
#
#     - Whatever raw data happened to pre-existing in the specific block of your RAM. Also it is good to be mindful because it will be randomand            unpredictable data

# %% [markdown]
# #### Flow Control Methods:

# %% [markdown]
# 1. Create an if statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable", however if 'age' is less than 25, print "Renting a car is very expensive."

# %%
age = input("... ")

if int (age) >= 25:
    print("Renting a car is more affordable")
else:
    print("Renting a car is very expensive.")
# Out:
# Renting a car is very expensive.

# %% [markdown]
# 2. Create and chain an if-else  statement: if 'age' is greater than or equal to 25, print "Renting a car is more affordable." If 'age' is less than 25 but greater than or equal to 18, print "Renting a car is very expensive." Finally, if age is less than 18, print "You cannot legally rent a car."

# %%
age = input("... ")

if int (age) >= 25:
    print("Renting a car is more affordable.")
elif age >= 18:
    print("Renting a car is very expensive.")
else:
    print("You cannot legally rent a car.")
# Out:
# Renting a car is more affordable.

# %% [markdown]
# 3. Loop over the following string to (1) count all the characters in the string and (2) print out all the vowels -- "The quick brown fox jumps over the lazy dog"

# %%
text = "The quick brown fox jumps over the lazy dog"

char_count = len(text)
print(f"Total character count: {char_count}")


vowels = "aeiouAEIOU"
print("Vowels found in the string:")
for char in text:
    if char in vowels:
        print(char)
# Out:
# Total character count: 43
# Vowels found in the string:
# e
# u
# i
# o
# o
# u
# o
# e
# e
# a
# o

# %% [markdown]
# 4. Write a nested loop that prints out every piece of clothing from the `couture` list, in every fashionable color from the `panettone` set: couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", "vest", "french beret", "scarf", "stole"] and panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", "burnt sienna", "gunmetal blue", "Dark Sapphire"}

# %%
couture = ["trousers", "blouse", "bandana", "cumber band", "blazer", 
           "vest", "french beret", "scarf", "stole"]
panettone = {"cerise", "fuchsia", "aqua", "maple", "auburn", 
             "burnt sienna", "gunmetal blue", "Dark Sapphire"}

for clothing in couture:
    for color in panettone:
        print(f"{color} {clothing}")
# Out:
# auburn trousers
# gunmetal blue trousers
# Dark Sapphire trousers
# fuchsia trousers
# burnt sienna trousers
# cerise trousers
# maple trousers
# aqua trousers
# auburn blouse
# gunmetal blue blouse
# Dark Sapphire blouse
# fuchsia blouse
# burnt sienna blouse
# cerise blouse
# maple blouse
# aqua blouse
# auburn bandana
# gunmetal blue bandana
# Dark Sapphire bandana
# fuchsia bandana
# burnt sienna bandana
# cerise bandana
# maple bandana
# aqua bandana
# auburn cumber band
# gunmetal blue cumber band
# Dark Sapphire cumber band
# fuchsia cumber band
# burnt sienna cumber band
# cerise cumber band
# maple cumber band
# aqua cumber band
# auburn blazer
# gunmetal blue blazer
# Dark Sapphire blazer
# fuchsia blazer
# burnt sienna blazer
# cerise blazer
# maple blazer
# aqua blazer
# auburn vest
# gunmetal blue vest
# Dark Sapphire vest
# fuchsia vest
# burnt sienna vest
# cerise vest
# maple vest
# aqua vest
# auburn french beret
# gunmetal blue french beret
# Dark Sapphire french beret
# fuchsia french beret
# burnt sienna french beret
# cerise french beret
# maple french beret
# aqua french beret
# auburn scarf
# gunmetal blue scarf
# Dark Sapphire scarf
# fuchsia scarf
# burnt sienna scarf
# cerise scarf
# maple scarf
# aqua scarf
# auburn stole
# gunmetal blue stole
# Dark Sapphire stole
# fuchsia stole
# burnt sienna stole
# cerise stole
# maple stole
# aqua stole

# %% [markdown]
# 5. Use range as a loop to calculate the sum of all the numbers from 1 to 100

# %%
for number in range(1, 100):
    total_sum += number


print("The sum of numbers from 1 to 100 is:", total_sum)
# Out:
# The sum of numbers from 1 to 100 is: 19800

# %% [markdown]
# 6. Print the second item in this fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[1])
# Out:
# banana

# %% [markdown]
# 7. Change the value from "apple" to "kiwi", in the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits[0] = "kiwi"

print(fruits)
# Out:
# ['kiwi', 'banana', 'cherry']

# %% [markdown]
# 8. Use the append method to add "orange" to the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")

print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# 9. Use the insert method to add "lemon" as the second item in the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.insert(1, "lemon")

print(fruits)
# Out:
# ['apple', 'lemon', 'banana', 'cherry']

# %% [markdown]
# 10. Use the remove method to remove "banana" from the fruits list.
#     ["apple", "banana", "cherry"]

# %%
fruits = ["apple", "banana", "cherry"]
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# 11. Use negative indexing to print the 3rd and 2nd to last items in the list.
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# 3rd to last item
print(fruits[-3])

# 2nd to last item
print(fruits[-2])
# Out:
# kiwi
# melon

# %% [markdown]
# 12. Use a range of indexes to print the third, fourth, and fifth item in the list.
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
fruits = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(fruits[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %% [markdown]
# 13. Use the correct syntax to print the number of items in the list.
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
mylist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(len(mylist))
# Out:
# 7

# %% [markdown]
# 14. Use the correct syntax to sort this list in reverse order
#     ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %%
list = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
list.sort(reverse=True)
print(list)
# Out:
# ['orange', 'melon', 'mango', 'kiwi', 'cherry', 'banana', 'apple']

# %% [markdown]
# 15. Use the DateTime module to get Current Date and Time, and save it to a variable. Then extract just the Full month name form that variable.

# %%
from datetime import datetime


current_datetime = datetime.now()

#Extract just the full month name from the variable***
full_month_name = current_datetime.strftime("%B")


print("Current Datetime:", current_datetime)
print("Full Month Name:", full_month_name)
# Out:
# Current Datetime: 2026-09-16 20:46:13.893833
# Full Month Name: September

# %% [markdown]
# 16. Write a simple function that takes 2 parameters -- a  first name and a day name.
#     - Set a default value for the day name of Sunday.
#     - Have the function print out a greeting -- using the parameters -- that says something like "Hi first-name! Happy day-name!". Remember to use the variables in the greeting to replace first-name and day-name.
#     - Invoke this function with 2 variables.
#     - Invoke this function with 1 variable only.

# %%
def greet_user(first_name, day_name="Sunday"):
    print(f"Hi {first_name}! Happy {day_name}!")


greet_user("Blake", "Friday")


greet_user("Buddy")
# Out:
# Hi Blake! Happy Friday!
# Hi Buddy! Happy Sunday!

# %% [markdown]
# 17. Write a block of code to handle one of the most common Python exception errors. Select one of the common errors from the curriculum section on Python Exception handling. Have your code example uses the `try`,`except`, `else`, and `finally` components.

# %%
try:
    numerator = 100
    denominator = 0
    result = numerator / denominator
except ZeroDivisionError:
    print("Error: You cannot divide by zero!")
else:
    print(f"Success! The result is {result}")
finally:
    print("Execution of the division check is complete.")
# Out:
# Error: You cannot divide by zero!
# Execution of the division check is complete.
